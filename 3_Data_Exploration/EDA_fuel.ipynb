# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Capstone-KPMG/3_Data_Exploration/12_Gas_Station
# !ls
fuel = pd.read_csv('fuel_point.csv').rename(columns={'Y':'Latitude','X':'Longitude'})
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1vvRy60J06fZq-dj8EPVTkgHU4gq8OCqU/Capstone-KPMG/Data_Exploration/Gas_Station
# fuel_point.csv	fuel_polygon.csv

# %%
fuel_poly = pd.read_csv('fuel_polygon.csv').rename(columns={'Y':'Latitude','X':'Longitude'})

# %%
fuel = pd.concat([fuel[['Longitude','Latitude','name']],fuel_poly[['Longitude','Latitude','name']]],axis=0)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Capstone-KPMG/Modeling/Data

fuel.to_csv('/content/drive/My Drive/Capstone-KPMG/4_Preprocessing/Data/fuel.csv',index=False)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1vvRy60J06fZq-dj8EPVTkgHU4gq8OCqU/Capstone-KPMG/Modeling/Data

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Capstone-KPMG/3_Data_Exploration/4_EVChargingStationLocations
# !ls
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1vvRy60J06fZq-dj8EPVTkgHU4gq8OCqU/Capstone-KPMG/Data_Exploration/4_EVChargingStationLocations
# 'alt_fuel_stations(Sep_25_2022).csv'

# %%
EV_station = pd.read_csv('alt_fuel_stations(Sep_25_2022).csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (20,31,39,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
EV_station = EV_station[EV_station['Fuel Type Code']=='ELEC']
EV_station = EV_station[EV_station['State']=='WA']

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/My Drive/Capstone-KPMG/Modeling/Data

EV_station.to_csv('/content/drive/My Drive/Capstone-KPMG/4_Preprocessing/Data/EV_station.csv',index=False)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1vvRy60J06fZq-dj8EPVTkgHU4gq8OCqU/Capstone-KPMG/Modeling/Data
